# %% [markdown]
# Read Json **files**

# %%
import json
import os

all_intents = []
directory_path = 'sample_data/'

for filename in os.listdir(directory_path):
    if filename.endswith('.json'):
        file_path = os.path.join(directory_path, filename)
        with open(file_path, 'r') as file:
            data = json.load(file)
            # Ensure 'data' is a dictionary
            if isinstance(data, dict):
                all_intents.extend(data.get('intents', []))

intents = all_intents
intents
# Out:
# [{'tag': 'greeting',
#   'patterns': ['Hi',
#    'How are you?',
#    'Is anyone there?',
#    'Hello',
#    'Good day',
#    "What's up",
#    'how are ya',
#    'heyy',
#    'whatsup',
#    '??? ??? ??'],
#   'responses': ['Hello!',
#    'Good to see you again!',
#    'Hi there, how can I help?'],
#   'context_set': ''},
#  {'tag': 'goodbye',
#   'patterns': ['cya',
#    'see you',
#    'bye bye',
#    'See you later',
#    'Goodbye',
#    'I am Leaving',
#    'Bye',
#    'Have a Good day',
#    'talk to you later',
#    'ttyl',
#    'i got to go',
#    'gtg'],
#   'responses': ['Sad to see you go :(',
#    'Talk to you later',
#    'Goodbye!',
#    'Come back soon'],
#   'context_set': ''},
#  {'tag': 'creator',
#   'patterns': ['what is the name of your developers',
#    'what is the name of your creators',
#    'what is the name of the developers',
#    'what is the name of the creators',
#    'who created you',
#    'your developers',
#    'your creators',
#    'who are your developers',
#    'developers',
#    'you are made by',
#    'you are made by whom',
#    'who created you',
#    'who create you',
#    'creators',
#    'who made you',
#    'who designed you'],
#   'responses': ['College students'],
#   'context_set': ''},
#  {'tag': 'name',
#   'patterns': ['name',
#    'your name',
#    'do you have a name',
#    'what are you called',
#    'what is your name',
#    'what should I call you',
#    'whats your name?',
#    'what are you',
#    'who are you',
#    'who is this',
#    'what am i chatting to',
#    'who am i taking to',
#    'what are you'],
#   'responses': ['You can call me Mind Reader.',
#    "I'm Mind Reader",
#    'I am a Chatbot.',
#    'I am your helper'],
#   'context_set': ''},
#  {'tag': 'hours',
#   'patterns': ['timing of college',
#    'what is college timing',
#    'working days',
#    'when are you guys open',
#    'what are your hours',
#    'hours of operation',
#    'when is the college open',
#    'college timing',
#    'what about college timing',
#    'is college open on saturday',
#    'tell something about college timing',
#    'what is the college  hours',
#    'when should i come to college',
#    'when should i attend college',
#    'what is my college time',
#    'college timing',
#    'timing college'],
#   'responses': ['College is open 8am-5pm Monday-Saturday!'],
#   'context_set': ''},
#  {'tag': 'number',
#   'patterns': ['more info',
#    'contact info',
#    'how to contact college',
#    'college telephone number',
#    'college number',
#    'What is your contact no',
#    'Contact number?',
#    'how to call you',
#    'College phone no?',
#    'how can i contact you',
#    'Can i get your phone number',
#    'how can i call you',
#    'phone number',
#    'phone no',
#    'call'],
#   'responses': ['You can contact at: NUMBER'],
#   'context_set': ''},
#  {'tag': 'course',
#   'patterns': ['list of courses',
#    'list of courses offered',
#    'list of courses offered in',
#    'what are the courses offered in your college?',
#    'courses?',
#    'courses offered',
#    'courses offered in (your univrsity(UNI) name)',
#    'courses you offer',
#    'branches?',
#    'courses available at UNI?',
#    'branches available at your college?',
#    'what are the courses in UNI?',
#    'what are branches in UNI?',
#    'what are courses in UNI?',
#    'branches available in UNI?',
#    'can you tell me the courses available in UNI?',
#    'can you tell me the branches available in UNI?',
#    'computer engineering?',
#    'computer',
#    'Computer engineering?',
#    'it',
#    'IT',
#    'Information Technology',
#    'AI/Ml',
#    'Mechanical engineering',
#    'Chemical engineering',
#    'Civil engineering'],
#   'responses': ['Our university offers Information Technology, computer Engineering, Mechanical engineering,Chemical engineering, Civil engineering and extc Engineering.'],
#   'context_set': ''},
#  {'tag': 'fees',
#   'patterns': ['information about fee',
#    'information on fee',
#    'tell me the fee',
#    'college fee',
#    'fee per semester',
#    'what is the fee of each semester',
#    'what is the fees of each year',
#    'what is fee',
#    'what is the fees',
#    'how much is the fees',
#    'fees for first year',
#    'fees',
#    'about the fees',
#    'tell me something about the fees',
#    'What is the fees of hostel',
#    'how much is the fees',
#    'hostel fees',
#    'fees for AC room',
#    'fees for non-AC room',
#    'fees for Ac room for girls',
#    'fees for non-Ac room for girls',
#    'fees for Ac room for boys',
#    'fees for non-Ac room for boys'],
#   'responses': ['For Fee detail visit <a target="_blank" href="LINK"> here</a>'],
#   'context_set': ''},
#  {'tag': 'location',
#   'patterns': ['where is the college located',
#    'college is located at',
#    'where is college',
#    'where is college located',
#    'address of college',
#    'how to reach college',
#    'college location',
#    'college address',
#    'wheres the college',
#    'how can I reach college',
#    'whats is the college address',
#    'what is the address of college',
#    'address',
#    'location'],
#   'responses': ['<a target="_blank" href="ADD YOU GOOGLE MAP LINK HERE"> here</a>'],
#   'context_set': ''},
#  {'tag': 'hostel',
#   'patterns': ['hostel facility',
#    'hostel servive',
#    'hostel location',
#    'hostel address',
#    'hostel facilities',
#    'hostel fees',
#    'Does college provide hostel',
#    'Is there any hostel',
#    'Where is hostel',
#    'do you have hostel',
#    'do you guys have hostel',
#    'hostel',
#    'hostel capacity',
#    'what is the hostel fee',
#    'how to get in hostel',
#    'what is the hostel address',
#    'how far is hostel from college',
#    'hostel college distance',
#    'where is the hostel',
#    'how big is the hostel',
#    'distance between college and hostel',
#    'distance between hostel and college'],
#   'responses': ['For hostel detail visit <a target="_blank" href="ADD YOUR HOSTEL DETAIL PDF LINK OR ANY INFORMATION LINK OR ADD YOU OWN ANSWERS"> here</a>'],
#   'context_set': ''},
#  {'tag': 'event',
#   'patterns': ['events organised',
#    'list of events',
#    'list of events organised in college',
#    'list of events conducted in college',
#    'What events are conducted in college',
#    'Are there any event held at college',
#    'Events?',
#    'functions',
#    'what are the events',
#    'tell me about events',
#    'what about events'],
#   'responses': ['For event detail visit <a target="_blank" href="ADD YOUR FUNCTIONS LINK OR YOUR OWN RESPONSE"> here</a>'],
#   'context_set': ''},
#  {'tag': 'floors',
#   'patterns': ['size of campus',
#    'building size',
#    'How many floors does college have',
#    'floors in college',
#    'floors in college',
#    "how tall is UNI's College of Engineering college building",
#    'floors'],
#   'responses': ['My College has total 2 floors '],
#   'context_set': ''},
#  {'tag': 'syllabus',
#   'patterns': ['Syllabus for IT',
#    'what is the Information Technology syllabus',
#    'syllabus',
#    'timetable',
#    'what is IT syllabus',
#    'syllabus',
#    'What is next lecture'],
#   'responses': ['Timetable provide direct to the students OR To know about syllabus visit <a target="_blank" href="TIMETABLE LINK"> here</a>'],
#   'context_set': ''},
#  {'tag': 'infrastructure',
#   'patterns': ['how is college infrastructure',
#    'infrastructure',
#    'college infrastructure'],
#   'responses': ['Our University has Excellent Infrastructure. Campus is clean. Good IT Labs With Good Speed of Internet connection'],
#   'context_set': ''},
#  {'tag': 'canteen',
#   'patterns': ['food facilities',
#    'canteen facilities',
#    'canteen facility',
#    'is there any canteen',
#    'Is there a cafetaria in college',
#    'Does college have canteen',
#    'Where is canteen',
#    'where is cafetaria',
#    'canteen',
#    'Food',
#    'Cafetaria'],
#   'responses': ['Our university has canteen with variety of food available'],
#   'context_set': ''},
#  {'tag': 'menu',
#   'patterns': ['food menu',
#    'food in canteen',
#    'Whats there on menu',
#    'what is available in college canteen',
#    'what foods can we get in college canteen',
#    'food variety',
#    'What is there to eat?'],
#   'responses': ['we serve Franky, Locho, Alu-puri, Kachori, Khavsa, Thaali and many more on menu'],
#   'context_set': ''},
#  {'tag': 'placement',
#   'patterns': ['What is college placement',
#    'Which companies visit in college',
#    'What is average package',
#    'companies visit',
#    'package',
#    'About placement',
#    'placement',
#    'recruitment',
#    'companies'],
#   'responses': ['To know about placement visit <a target="_blank" href="PLACEMENT INFORMATION LINK FROM YOUR UNIVERSITY WEBSITE IF THEY HAVE">here</a>'],
#   'context_set': ''},
#  {'tag': 'ithod',
#   'patterns': ['Who is HOD', 'Where is HOD', 'it hod', 'name of it hod'],
#   'responses': ['All engineering departments have only one hod XYZ who available on (Place name)'],
#   'context_set': ''},
#  {'tag': 'computerhod',
#   'patterns': ['Who is computer HOD',
#    'Where is computer HOD',
#    'computer hod',
#    'name of computer hod'],
#   'responses': ['All engineering departments have only one hod XYZ who available on (PLACE NAME)'],
#   'context_set': ''},
#  {'tag': 'extchod',
#   'patterns': ['Who is extc HOD',
#    'Where is  extc HOD',
#    'extc hod',
#    'name of extc hod'],
#   'responses': ['Different school wise hod are different.So be more clear with your school or department'],
#   'context_set': ''},
#  {'tag': 'principal',
#   'patterns': ['what is the name of principal',
#    'whatv is the principal name',
#    'principal name',
#    'Who is college principal',
#    "Where is principal's office",
#    'principal',
#    'name of principal'],
#   'responses': ['XYZ is college principal and if you need any help then call your branch hod first.That is more appropriate'],
#   'context_set': ''},
#  {'tag': 'sem',
#   'patterns': ['exam dates',
#    'exam schedule',
#    'When is semester exam',
#    'Semester exam timetable',
#    'sem',
#    'semester',
#    'exam',
#    'when is exam',
#    'exam timetable',
#    'exam dates',
#    'when is semester'],
#   'responses': ['Here is the Academic Calendar  <a target="_blank" href="YOUR ACADEMIC CALENDER">website</a>'],
#   'context_set': ''},
#  {'tag': 'admission',
#   'patterns': ['what is the process of admission',
#    'what is the admission process',
#    'How to take admission in your college',
#    'What is the process for admission',
#    'admission',
#    'admission process'],
#   'responses': ['Application can also be submitted online through the Unversity\'s  <a target="_blank" href="LINK OF ADMISSION DOCUMENT">website</a>'],
#   'context_set': ''},
#  {'tag': 'scholarship',
#   'patterns': ['scholarship',
#    'Is scholarship available',
#    'scholarship engineering',
#    'scholarship it',
#    'scholarship ce',
#    'scholarship mechanical',
#    'scholarship civil',
#    'scholarship chemical',
#    'scholarship for AI/ML',
#    'available scholarships',
#    'scholarship for computer engineering',
#    'scholarship for IT engineering',
#    'scholarship for mechanical engineering',
#    'scholarship for civil engineering',
#    'scholarship for chemical engineering',
#    'list of scholarship',
#    'comps scholarship',
#    'IT scholarship',
#    'mechanical scholarship',
#    'civil scholarship',
#    'chemical scholarship',
#    'automobile scholarship',
#    'first year scholarship',
#    'second year scholarship',
#    'third year scholarship',
#    'fourth year scholarship'],
#   'responses': ['Many government scholarships are supported by our university. For details and updates visit <a target="_blank" href="(SCHOLARSHIP DETAILS LINK)">here</a>'],
#   'context_set': ''},
#  {'tag': 'facilities',
#   'patterns': ['What facilities college provide',
#    'College facility',
#    'What are college facilities',
#    'facilities',
#    'facilities provided'],
#   'responses': ["Our university's Engineering department provides fully AC Lab with internet connection, smart classroom, Auditorium, library,canteen"],
#   'context_set': ''},
#  {'tag': 'college intake',
#   'patterns': ['max number of students',
#    'number of seats per branch',
#    'number of seats in each branch',
#    'maximum number of seats',
#    'maximum students intake',
#    'What is college intake',
#    'how many stundent are taken in each branch',
#    'seat allotment',
#    'seats'],
#   'responses': ['For IT, Computer and extc 60 per branch and seat may be differ for different department.'],
#   'context_set': ''},
#  {'tag': 'uniform',
#   'patterns': ['college dress code',
#    'college dresscode',
#    'what is the uniform',
#    'can we wear casuals',
#    'Does college have an uniform',
#    'Is there any uniform',
#    'uniform',
#    'what about uniform',
#    'do we have to wear uniform'],
#   'responses': ['ENTER YOUR OWN UNIVERSITY UNIFORM CIRCULER'],
#   'context_set': ''},
#  {'tag': 'committee',
#   'patterns': ['what are the different committe in college',
#    'different committee in college',
#    'Are there any committee in college',
#    'Give me committee details',
#    'committee',
#    'how many committee are there in college'],
#   'responses': ['For the various committe in college contact this number: ADD NUMBER'],
#   'context_set': ''},
#  {'tag': 'random',
#   'patterns': ['I love you', 'Will you marry me', 'Do you love me'],
#   'responses': ['I am not program for this, please ask appropriate query'],
#   'context_set': ''},
#  {'tag': 'swear',
#   'patterns': ['fuck',
#    'bitch',
#    'shut up',
#    'hell',
#    'stupid',
#    'idiot',
#    'dumb ass',
#    'asshole',
#    'fucker'],
#   'responses': ['please use appropriate language',
#    'Maintaining decency would be appreciated'],
#   'context_set': ''},
#  {'tag': 'vacation',
#   'patterns': ['holidays',
#    'when will semester starts',
#    'when will semester end',
#    'when is the holidays',
#    'list of holidays',
#    'Holiday in these year',
#    'holiday list',
#    'about vacations',
#    'about holidays',
#    'When is vacation',
#    'When is holidays',
#    'how long will be the vacation'],
#   'responses': ['Academic calender is given to you by your class-soordinators after you join your respective classes'],
#   'context_set': ''},
#  {'tag': 'sports',
#   'patterns': ['sports and games',
#    'give sports details',
#    'sports infrastructure',
#    'sports facilities',
#    'information about sports',
#    'Sports activities',
#    'please provide sports and games information'],
#   'responses': ['Our university encourages all-round development of students and hence provides sports facilities in the campus. For more details visit<a target="_blank" href=/"(LINK IF HAVE)">here</a>'],
#   'context_set': ''},
#  {'tag': 'salutaion',
#   'patterns': ['okk',
#    'okie',
#    'nice work',
#    'well done',
#    'good job',
#    'thanks for the help',
#    'Thank You',
#    'its ok',
#    'Thanks',
#    'Good work',
#    'k',
#    'ok',
#    'okay'],
#   'responses': ['I am glad I helped you',
#    'welcome, anything else i can assist you with?'],
#   'context_set': ''},
#  {'tag': 'task',
#   'patterns': ['what can you do',
#    'what are the thing you can do',
#    'things you can do',
#    'what can u do for me',
#    'how u can help me',
#    'why i should use you'],
#   'responses': ['I can answer to low-intermediate questions regarding college',
#    'You can ask me questions regarding college, and i will try to answer them'],
#   'context_set': ''},
#  {'tag': 'ragging',
#   'patterns': ['ragging',
#    'is ragging practice active in college',
#    'does college have any antiragging facility',
#    'is there any ragging cases',
#    'is ragging done here',
#    'ragging against',
#    'antiragging facility',
#    'ragging juniors',
#    'ragging history',
#    'ragging incidents'],
#   'responses': ['We are Proud to tell you that our college provides ragging free environment, and we have strict rules against ragging'],
#   'context_set': ''},
#  {'tag': 'hod',
#   'patterns': ['hod', 'hod name', 'who is the hod'],
#   'responses': ['HODs differ for each branch, please be more specific like: (HOD it)'],
#   'context_set': ''},
#  {'tag': '', 'patterns': [], 'responses': [], 'context_set': ''},
#  {'tag': 'fees',
#   'patterns': ['How much are the fees for this year',
#    'tell me the fees of my academic year',
#    'much fees year',
#    'tell fees academic year',
#    'fees'],
#   'responses': ['you can know the fees from here: http://myhu.helwan.edu.eg/login'],
#   'context_set': ''},
#  {'tag': ['Timetable', 'schedule'],
#   'patterns': ['give me the time table',
#    'give me the schedule',
#    'give time table',
#    'give schedule'],
#   'responses': ['you will find the time table here: http://education.fcih.helwan.edu.eg/portal/student/dashboard'],
#   'context_set': ''},
#  {'tag': ['material', 'Convex'],
#   'patterns': ['give me some material for convex please',
#    'give material convex please',
#    'convex material',
#    'convex',
#    'send convex lectures'],
#   'responses': ['you can find some material for convex here : https://www.youtube.com/watch?v=McLq1hEq3UY&list=PL3940DD956CDF0622'],
#   'context_set': ''},
#  {'tag': ['material', 'AI'],
#   'patterns': ['i need some material for ai',
#    'give me material for ai',
#    'ai lectures',
#    'ai project',
#    'send more material fos ai',
#    'need material ai',
#    'ai material'],
#   'responses': ['Amr ghoneim playlist for AI : https://www.youtube.com/watch?v=sO6VGgBHppo&list=PLsnvpvHuTUbAZr0n65TgytBK6bHdT33A7',
#    'AI lectures by marwan: https://drive.google.com/drive/folders/1aiBeFhpmFmzdTQPzxKx6ZiRyPfo7-xY2?usp=sharing',
#    'DR. Amr drive: https://drive.google.com/drive/folders/1idzWQqb_Fb-BPLBPABPRMYLE-Pr7AS8j?fbclid=IwAR096X9bGtoixCqPy6ix9QN1sPa62mMCJF4QoL1PF4WJ0zaoP6Dj4ToiYJk'],
#   'context_set': ''},
#  {'tag': ['material', 'SA'],
#   'patterns': ['i need some material for sa',
#    'give me material for sa',
#    'sa lectures',
#    'sa project',
#    'send more material fos sa',
#    'need material sa',
#    'sa material',
#    'sa'],
#   'responses': ['here is some materials for sa made by marawan mohamed : https://www.youtube.com/watch?v=ggGmXba7yYU&list=PLjQhZRrolr67Nkq7ZYXfkUt87Q_6B5VxJ&pp=iAQB',
#    'here you can find D.MohamedEldesoky playlist for sa: https://www.youtube.com/watch?v=9jrN5BPx4MI&list=PL1DUmTEdeA6I-bsfaErW12ro4_6hC7fSp '],
#   'context_set': ''},
#  {'tag': ['material', 'ML'],
#   'patterns': ['i need some material for ML',
#    'send ml lectures',
#    'need material ml',
#    'ml',
#    'ml material',
#    'machine learning'],
#   'responses': ['Hesham asem playlist for ML : https://www.youtube.com/watch?v=5_GKIhoXKyI&list=PL6-3IRz2XF5UJE2PbY7UU4SHi7UpV1mXo'],
#   'context_set': ''},
#  {'tag': 'Exams',
#   'patterns': ['can you tell me the location of my exam?',
#    'tell location exam',
#    'i want to know when my exams',
#    'want know exams'],
#   'responses': ['you can know informations about your exams from this link: http://education.fcih.helwan.edu.eg/portal/student/exams-timess'],
#   'context_set': ''},
#  {'tag': ['material', 'db2'],
#   'patterns': ['send db2 lectures',
#    'i need database2 material',
#    'send lectures',
#    'need material'],
#   'responses': ['you will find db2 material here for Dr Iyad Husni: https://www.youtube.com/watch?v=J5_pw5HP2JM&list=PLbJQU7iCpoGBdA-DtxlFxJ9rAyzUlLw2r',
#    'Mohamed Eldesouky playlist for database2: https://www.youtube.com/watch?v=3VU16LGMqHI&list=PL1DUmTEdeA6LiVWHeITVLTQ6ht_5xPCh8'],
#   'context_set': ''},
#  {'tag': ['material', 'os2'],
#   'patterns': ['i need os2 materials',
#    'send operation system2 lectures',
#    'need materials',
#    'send operation lectures'],
#   'responses': ['you will find os2 material here: https://drive.google.com/drive/u/0/folders/1PXilRVUqKrl9vvi_ikJ0bTNCInwRutKy?fbclid=IwAR3IjNnkSdjmHFObOqOtUo47BrdnaebeimCkmTIIpO1fF13AagtkmryXN38'],
#   'context_set': ''},
#  {'tag': ['material', 'Multimedia'],
#   'patterns': ['send multimedia material',
#    'send multimedia lectures',
#    'multimedia lectures',
#    'multimedia material'],
#   'responses': ['here you will find multimedia material: https://drive.google.com/drive/u/0/folders/1WxDbU0tcEu9-aPyiL_hGRWWifaB0HRha?fbclid=IwAR3IjNnkSdjmHFObOqOtUo47BrdnaebeimCkmTIIpO1fF13AagtkmryXN38'],
#   'context_set': ''},
#  {'tag': ['Drive', 'TermMaterials'],
#   'patterns': ['send level3 material',
#    'send level3 lectures',
#    'i want the first term drive for level3',
#    'i want the second term drive for level3',
#    'send material',
#    'send lectures',
#    'want first term drive',
#    'want second term drive'],
#   'responses': ['here you will find some material for level3 https://drive.google.com/drive/u/0/folders/1PH0lBMNEFAd3eG4jajKfHILlbmaXkR6s?fbclid=IwAR3IjNnkSdjmHFObOqOtUo47BrdnaebeimCkmTIIpO1fF13AagtkmryXN38'],
#   'context_set': ''},
#  {'tag': 'Sections',
#   'patterns': ['give me sections timetable',
#    'give sections timetable',
#    'send sections file'],
#   'responses': [],
#   'context_set': ''},
#  {'tag': ['material', 'SE'],
#   'patterns': ['give me SE material',
#    'give se material',
#    'send Software Engineering playlist'],
#   'responses': ['here you can find Marawan Mohamed playlist for SE : https://www.youtube.com/watch?v=jJsFBWTzlow&list=PLjQhZRrolr64R92Y_A03tRiSAbzLZegkg&pp=iAQB'],
#   'context_set': ''},
#  {'tag': 'ByteExchange',
#   'patterns': ['what is ByteExchange',
#    'tell me about ByteExchange',
#    'byteexchange',
#    'tell byteexchange'],
#   'responses': ['byte Exchange,This is a group created by Marwan Mohamed to help students develop themselves in study and work'],
#   'context_set': ''},
#  {'tag': 'MarawanYT',
#   'patterns': ['Give me marawan mohamed youtube',
#    'i need youtube link for marawan mohamed channel',
#    'give marawan mohamed youtube',
#    'need youtube link marawan mohamed channel',
#    'marawan mohamed',
#    'marawan',
#    'marwan'],
#   'responses': ['here you will find marawan mohamed channnel: https://www.youtube.com/@Marwan-ol8ie/featured'],
#   'context_set': ''},
#  {'tag': 'AmrGhoneimYT',
#   'patterns': ['Give me Dr Amr Ghoneim channel',
#    'i need youtube link for amr ghoneim channel',
#    'give dr amr ghoneim channel',
#    'need youtube link amr ghoneim channel'],
#   'responses': ['here you will find amr ghoneim channel: https://www.youtube.com/@AmrSGhoneim'],
#   'context_set': ''},
#  {'tag': 'MohamedEldesokyYT',
#   'patterns': ['Give me mohamed eldesoky channel',
#    'i need youtube link for mohamed eldesoky channel',
#    'give mohamed eldesoky channel',
#    'need youtube link mohamed eldesoky channel'],
#   'responses': ['here you will find Mohemd Eldesoky channel:https://www.youtube.com/@DesoukiEgypt'],
#   'context_set': ''},
#  {'tag': 'EmailPattern',
#   'patterns': ['i want to know the college email pattern',
#    'i want to know my email in college',
#    'want know college email pattern',
#    'want know email college'],
#   'responses': ["Don't worry rafiki will help you, Email pattern is: YourName_YourID@fci.helwan.edu.eg"],
#   'context_set': ''},
#  {'tag': 'CollegeSite',
#   'patterns': ['send fcai facebook page',
#    'give me the facebook page for our college',
#    'give facebook page college'],
#   'responses': ['here you will find the Fcai official group : https://www.facebook.com/groups/435176807905112'],
#   'context_set': ''},
#  {'tag': 'locations',
#   'patterns': ['send all the locations for all labs and halls',
#    'send locations labs halls'],
#   'responses': ['here you will find all the locations : https://www.facebook.com/photo/?fbid=10168501081815643&set=gm.790437072379082&idorvanity=435176807905112'],
#   'context_set': ''},
#  {'tag': 'HossamShamardan',
#   'patterns': ['who is hossam shamardan?',
#    'tell me about hossam shamardan',
#    'hossam shamardan',
#    'tell hossam shamardan'],
#   'responses': ["it's better not to say", "i can't say this here"],
#   'context_set': ''},
#  {'tag': 'SecondYear',
#   'patterns': ['send my second term material for level2 ',
#    'i need some material for level2',
#    'send second term material',
#    'need material'],
#   'responses': ['here you will find some material for level2 secondterm: https://drive.google.com/drive/u/0/folders/1WWyG9zerNf_OZtkJVqDpqcHvUZVg8is_  , and some exams:https://drive.google.com/drive/folders/16hz1sYlF-wYLSN8CMSFR44-uYTaHvhjb'],
#   'context_set': ''},
#  {'tag': ['material', 'BigData'],
#   'patterns': ['i need some materials for BigData',
#    'send bigdata teams group',
#    'need materials bigdata'],
#   'responses': ['you will find big data material here: https://teams.microsoft.com/l/channel/19%3aXG1Gnbu3S1gOvd3v8zVReBDFoSrX2Zl9OYm5FvLOSBs1%40thread.tacv2/General?groupId=afc7175d-5d91-4feb-96f0-cca1683920b3&tenantId=aadc0e0a-65ee-471a-99a1-9f86faecbaed'],
#   'context_set': ''},
#  {'tag': ['material', 'algorithms'],
#   'patterns': ['send algorithms material',
#    'i need algorithms lectures',
#    'send algorithms drive and channel link',
#    'need algorithms lectures',
#    'send algorithms drive channel link'],
#   'responses': ['Algorithms material..  Drive Link : https://bit.ly/3qFuNoZ , Channel Link : https://bit.ly/3Lcaibg'],
#   'context_set': ''},
#  {'tag': ['material', 'Discrete'],
#   'patterns': ['give me discrete maths material',
#    'i want discrete maths playlist',
#    'give discrete maths material',
#    'want discrete maths playlist'],
#   'responses': ['here is the playlist for disccrete maths: https://youtube.com/playlist?list=PLp4VgraT9FJB0n-RLmMcqLoO4nVYwQZEU'],
#   'context_set': ''},
#  {'tag': 'RegisterCourses',
#   'patterns': ['Give me register courses link',
#    'i want to register courses',
#    'give register courses link',
#    'want register courses'],
#   'responses': ['here is the link: http://education.fcih.helwan.edu.eg/portal/student/register-courses'],
#   'context_set': ''},
#  {'tag': 'هلس',
#   'patterns': ['ممكن تيجي الامتحان معايا بكرا',
#    'ممكن تحل الكلام دة',
#    'ممكن تشرحلي'],
#   'responses': ['رفيقك تعبان دلوقتي ممكن تكلمه بعدين'],
#   'context_set': ''},
#  {'tag': '', 'patterns': [], 'responses': [], 'context_set': ''},
#  {'tag': 'class',
#   'patterns': ['class 1',
#    'class 2',
#    'where is class 1',
#    'where is class 2',
#    'where class 1',
#    'where class 2'],
#   'responses': ['In Floor 0', 'In Basement'],
#   'context_set': ''},
#  {'tag': 'hall',
#   'patterns': ['hall 3',
#    'hall 4',
#    'where is hall 3',
#    'where is hall 4',
#    'where hall 3',
#    'where hall 4'],
#   'responses': ['In Floor 0', 'In Basement'],
#   'context_set': ''},
#  {'tag': 'room',
#   'patterns': ['room 1',
#    'room 2',
#    'where is room 1',
#    'where is room 2',
#    'where room 1',
#    'where room 2'],
#   'responses': ['In Floor 0', 'In Basement'],
#   'context_set': ''},
#  {'tag': 'lab',
#   'patterns': ['lab 1',
#    'lab 2',
#    'lab 3',
#    'lab 4',
#    'lab 5',
#    'lab 6',
#    'where is lab 1',
#    'where is lab 2',
#    'where is lab 3',
#    'where is lab 4',
#    'where is lab 5',
#    'where is lab 6',
#    'where lab 1',
#    'where lab 2',
#    'where lab 3',
#    'where lab 4',
#    'where lab 5',
#    'where lab 6'],
#   'responses': ['In Floor 1', 'in the right when You inter fcaih'],
#   'context_set': ''},
#  {'tag': 'hall',
#   'patterns': ['hall 1', 'where is hall 1', 'where hall 1'],
#   'responses': ['In Floor 1', 'First floor'],
#   'context_set': ''},
#  {'tag': 'hall',
#   'patterns': ['hall 7', 'where is hall 7', 'where hall 7'],
#   'responses': ['In Floor 2', 'Second floor'],
#   'context_set': ''},
#  {'tag': 'hall',
#   'patterns': ['hall 2',
#    'where is hall 2',
#    'where hall 2',
#    'hall 8',
#    'where is hall 8',
#    'where hall 8',
#    'hall 5',
#    'where is hall 5',
#    'where hall 5'],
#   'responses': ['In Floor 3', 'Third floor'],
#   'context_set': ''},
#  {'tag': 'lab',
#   'patterns': ['lab 7',
#    'where is lab 7',
#    'where lab 7',
#    'lab m',
#    'where is lab m',
#    'where lab m',
#    'lab 13',
#    'where is lab 13',
#    'where lab 13'],
#   'responses': ['In Floor 2', 'Second floor'],
#   'context_set': ''},
#  {'tag': 'lab',
#   'patterns': ['lab 8',
#    'where is lab 8',
#    'where lab 8',
#    'electronic lab',
#    'where is electronic lab',
#    'where electronic lab',
#    'lab 9',
#    'where is lab 9',
#    'where lab 9'],
#   'responses': ['In Floor 3', 'Third floor'],
#   'context_set': ''},
#  {'tag': 'lab',
#   'patterns': ['lab 10',
#    'where is lab 10',
#    'where lab 10',
#    'lab 11',
#    'where is lab 11',
#    'where lab 11',
#    'lab 12',
#    'where is lab 12',
#    'where lab 12'],
#   'responses': ['In Floor 4', 'Fourth floor', 'Last floor'],
#   'context_set': ''},
#  {'tag': 'hall',
#   'patterns': ['hall 6', 'where is hall 6', 'where hall 6'],
#   'responses': ['In Floor 4', 'Fourth floor', 'Last floor'],
#   'context_set': ''},
#  {'tag': 'class',
#   'patterns': ['class 4', 'where class 4', 'where is class 4'],
#   'responses': ['In Floor 4', 'Fourth floor', 'Last floor'],
#   'context_set': ''},
#  {'tag': ['specialization', 'is'],
#   'patterns': ['is specialization', 'specialization is', 'is'],
#   'responses': ['your nessessory subjects Database Systems – 2 ,Big Data ,Information Systems Security ,Data Storage and Retrieval & Business intelligence  then you can choose 2 subjects from rest'],
#   'context_set': ''},
#  {'tag': ['specialization', 'it'],
#   'patterns': ['it specialization', 'specialization it', 'it'],
#   'responses': ['your nessessory subjects AI, Computer Architecture ,Multimedia & Communication Technology then you can choose 2 subjects from rest'],
#   'context_set': ''},
#  {'tag': ['specialization', 'ai'],
#   'patterns': ['ai specialization', 'specialization ai', 'ai'],
#   'responses': ['your nessessory subjects Convex optimization, AI , Machine Learning & Big Data then you can choose 2 subjects from rest'],
#   'context_set': ''},
#  {'tag': 'channel',
#   'patterns': ['doctor mohamed said channel',
#    'mohamed said channel',
#    'doctor mohamed elsaid channel',
#    'mohamed elsaid channel',
#    'mohamed elsaid'],
#   'responses': ['You can watch dr.moahmed content:https://www.youtube.com/@DrMohammedElSaid'],
#   'context_set': ''},
#  {'tag': ['specialization', 'cs'],
#   'patterns': ['cs specialization', 'specialization cs', 'cs'],
#   'responses': ['your nessessory subjects AI , Machine Learning ,OS2 & Co then you can choose 2 subjects from rest'],
#   'context_set': ''},
#  {'tag': 'doctor',
#   'patterns': ['doctor amr',
#    'doctor amr ghoniem',
#    'amr',
#    'ghoneim',
#    'ghoniem',
#    'amr ghoniem',
#    'dr.amr ghoniem',
#    'who is doctor amr',
#    'who is doctor amr ghoniem'],
#   'responses': ['CS Academic, AI Researcher & the One Professor to Rule Them All 🇪🇬🇦🇺 \n Studied M.Sc. Computer Science - Machine Learning/Artificial Intelligence & Computational Linguistics M.Sc. Program at Helwan University \nProfessor at Faculty of Computers and Artificial Intelligence Helwan University'],
#   'context_set': ''},
#  {'tag': 'channel',
#   'patterns': ['doctor amr channel',
#    'amr channel',
#    'doctor amr ghoniem channel',
#    'amr ghoniem channel'],
#   'responses': ['You can watch dr.amr content:https://www.youtube.com/AmrSGhoneim channel conatin many courses like AI ,soft ware engeneering & intro to cs'],
#   'context_set': ''},
#  {'tag': 'doctor',
#   'patterns': ['doctor helal ahmed ',
#    'helal',
#    'helal ahmed',
#    'dr.helal ahmed'],
#   'responses': ['You can communicate with him via:helal.a.suleiman@outlook.com'],
#   'context_set': ''},
#  {'tag': 'doctor',
#   'patterns': ['doctor mohamed said',
#    'mohamed said',
#    'mohamed elsaid',
#    'dr.mohamed said',
#    'dr.mohamed elsaid'],
#   'responses': ['Mohammed is a passionate professional Software Engineer and Technical Software Architect, with 18+ years of career.\n He worked on a wide variety of projects with a wide variety of people from different cultures and backgrounds.\n throughout his career, he worked for many Software companies, he also founded and managed his own startup software house.\n He holds a master’s degree in Image Processing and a PhD. Degree in Natural Language Processing.'],
#   'context_set': ''},
#  {'tag': ['location', 'place', 'affair'],
#   'patterns': ['student affairs location ',
#    'affairs location',
#    'student',
#    'student affairs place ',
#    'affairs',
#    'affairs place'],
#   'responses': ['First floor at the end of corridor before stairs of basement'],
#   'context_set': ''},
#  {'tag': ['مكان الشؤون', 'الشؤون'],
#   'patterns': ['فين مكان الشؤون', 'الشؤون', 'فين الشؤون'],
#   'responses': ['اول ما تخش من باب الكليه هتلاقيها اخر الممر على الشمال قبل سلم البدروم'],
#   'context_set': ''},
#  {'tag': 'الشؤون',
#   'patterns': ['معلومات عن الشؤون', 'ممكن اعمل  الشؤون', 'شؤون الطلاب'],
#   'responses': ['ممكن تعمل اثبات قيد ممكن تسأل عن اى مشكله تقابلك كطالب و هما هيسعدوك ممكن تقدم اوراق و وصل المصاريف ممكن تختم ورق المترو هناك '],
#   'context_set': ''},
#  {'tag': ['المسجد', 'مسجد', 'صلاه'],
#   'patterns': ['مسجد', 'المسجد', 'اصلى فين', 'اين المسجد', 'فين المسجد'],
#   'responses': ['الدور الاول اول ما تطلع من السلم هتلاقيه على الشمال و حرما مقدما'],
#   'context_set': ''},
#  {'tag': 'greeting_arabic',
#   'patterns': ['اهلا', 'مرحبا', 'ازيك', 'صباح الخير', 'السلام عليكم'],
#   'responses': ['اهلا', 'ًصباح الخير, أقدر اساعدك ازاي؟']},
#  {'tag': 'greeting_english',
#   'patterns': ['Hi', 'Hey', 'Hello', 'good afternoon', 'good morning'],
#   'responses': ['Hello!',
#    'Hi, How can I help?',
#    'Hello! How can I assist you with food today?',
#    'Hi there! what food do you want ?',
#    'which food do you want ?']},
#  {'tag': 'location_arabic',
#   'patterns': ['فين الأكل',
#    'عايز مطعم',
#    'مكان المطاعم',
#    'فين المطعم',
#    'مكان المطعم',
#    'عايز أكل',
#    'أبحث عن مطعم',
#    'مطاعم الجامعة فين',
#    'فين مكان المطاعم',
#    'فين مكان المطاعم في الجامعة'],
#   'responses': ['جامعتنا فيها مطاعم كتير. ممكن تحدد موقعك الحالي عشان اساعدك؟',
#    'ايه أقرب مدرج او كلية ليك؟']},
#  {'tag': 'location_english',
#   'patterns': ['Where do I go to eat?',
#    "I'm hungry",
#    'Where are the university restaurants',
#    'I want to eat',
#    'find me somewhere to eat',
#    'where can i find delicious food?',
#    'where is the restuarant here?',
#    'where can i find food?'],
#   'responses': ["There are many places to eat across the campus. What's your current location so I can suggest somwhere nearby?"]},
#  {'tag': 'restaurant_suggestion_arabic',
#   'patterns': ['اقترح عليا اكل', 'اكل ايه؟'],
#   'responses': ['نفسك تاكل ايه دلوقتي؟ نجرسكو او سوري او بيتزا او سناكس؟']},
#  {'tag': 'restaurant_suggestion_english',
#   'patterns': ['Suggest somewhere to eat',
#    'Where do you think I should eat?',
#    'Suggest any place',
#    "What's for lunch?",
#    'Tell me about your menu',
#    'Recommend a dish'],
#   'responses': ['What kind of food would you like to order so I could recommend the best place for it? Would you like dishes like white sauce pasta? or pizza and sandwiches? or Would u like to buy snacks?']},
#  {'tag': 'pasta_recommendation_arabic',
#   'patterns': ['نفسي في نجرسكو', 'مكرونة بشاميل'],
#   'responses': ['جرب ويتش, بيعمل احسن مكرونة']},
#  {'tag': 'pasta_recommendation_english',
#   'patterns': ['i would like to order pasta',
#    'i would like to order negresco',
#    'i would like to order white sauce pasta'],
#   'responses': ['You should try Witch, it has the best reviews for pasta']},
#  {'tag': 'sandwiches_recommendation_arabic',
#   'patterns': ['نفسي في سندوتش بانيه', 'ساندوتش كرسبي', 'برجر'],
#   'responses': ['المروة عنده سندوتشات لذيذة. هتلاقيه جنب مدرج 17']},
#  {'tag': 'sandwiches_recommendation_english',
#   'patterns': ["i'm craving a chicken sandwich",
#    'i would like a beef burger',
#    'i would like a chicken burger',
#    'i want a crispy chicken sandwich'],
#   'responses': ["Then I'd suggest El Marwa, it has the best reviews for sandwiches"]},
#  {'tag': 'snacks_recommendation_arabic',
#   'patterns': ['سناكس و شيبسي', 'باتيه و عصير'],
#   'responses': ['الكافيتيريا في المول فيها كل انواع السناكس اللي عايزها']},
#  {'tag': 'snacks_recommendation_english',
#   'patterns': ['i would like to order snacks and drinks'],
#   'responses': ['The mall contains a variety of snacks and cafeteria for drinks']},
#  {'tag': 'syrian_recommendation_arabic',
#   'patterns': ['اكل سوري', 'سندوتش بطاطس سوري', 'شاورما'],
#   'responses': ['جرب مطعم المول, عنده كل الاكل السوري']},
#  {'tag': 'syrian_recommendation_english',
#   'patterns': ['I want to eat shawarma',
#    "I'm craving syrian food",
#    'which place serves the best syrian food',
#    'shawerma'],
#   'responses': ['I suggest you head to the Mall, it has the best syrian food.']},
#  {'tag': 'menu_arabic',
#   'patterns': ['عايز المنيو',
#    'الاسعار ايه',
#    'بكام؟',
#    'بقت بكام',
#    'عايز منيو كل مطعم',
#    'المنيو ؟'],
#   'responses': [{'id': 1,
#     'category': 'Meals of Witch',
#     'items': [{'name': 'باستا صوص ابيض', 'price': 30},
#      {'name': 'سندوتش بطاطس', 'price': 22},
#      {'name': 'برجر', 'price': 10.99},
#      {'name': 'كريب زنجر', 'price': 55},
#      {'name': 'كفتة', 'price': 35},
#      {'name': 'بيتزا فراح', 'price': 75},
#      {'name': 'بيتزا لحمة', 'price': 75},
#      {'name': 'بيتزا مارجريتا', 'price': 70},
#      {'name': 'بينزا تونا', 'price': 85},
#      {'name': 'بيتزا ميكس', 'price': 85},
#      {'name': 'بيتزا ميكس لحمة', 'price': 85}]},
#    {'id': 2,
#     'category': 'desserts of Witch',
#     'items': [{'name': 'مولتن كيك', 'price': 45},
#      {'name': 'تشيز كيك', 'price': 40},
#      {'name': 'كاب كيك', 'price': 30},
#      {'name': 'فطيرة شكولاتة', 'price': 35}]},
#    {'id': 3,
#     'category': 'drinks of Witch',
#     'items': [{'name': 'ايسد كوفي', 'price': 10},
#      {'name': 'سموزي', 'price': 30},
#      {'name': 'شاي', 'price': 10},
#      {'name': 'قهوة', 'price': 10},
#      {'name': 'بيبسي', 'price': 5},
#      {'name': 'نسكافيه', 'price': 15}]},
#    {'id': 4,
#     'category': 'Meals of Marwa',
#     'items': [{'name': 'باستا صوص ابيض', 'price': 30},
#      {'name': 'سندوتش بطاطس', 'price': 22},
#      {'name': 'برجر', 'price': 10.99},
#      {'name': 'كريب زنجر', 'price': 55},
#      {'name': 'كفتة', 'price': 35},
#      {'name': 'بيتزا فراح', 'price': 75},
#      {'name': 'بيتزا لحمة', 'price': 75},
#      {'name': 'بيتزا مارجريتا', 'price': 70},
#      {'name': 'بينزا تونا', 'price': 85},
#      {'name': 'بيتزا ميكس', 'price': 85},
#      {'name': 'بيتزا ميكس لحمة', 'price': 85}]},
#    {'id': 5,
#     'category': 'desserts of Marwa',
#     'items': [{'name': 'مولتن كيك', 'price': 45},
#      {'name': 'تشيز كيك', 'price': 40},
#      {'name': 'كاب كيك', 'price': 30},
#      {'name': 'فطيرة شكولاتة', 'price': 35}]},
#    {'id': 6,
#     'category': 'drinks of Marwa',
#     'items': [{'name': 'ايسد كوفي', 'price': 10},
#      {'name': 'سموزي', 'price': 30},
#      {'name': 'شاي', 'price': 10},
#      {'name': 'قهوة', 'price': 10},
#      {'name': 'بيبسي', 'price': 5},
#      {'name': 'نسكافيه', 'price': 15}]},
#    {'id': 7,
#     'category': 'Meals of Africanno',
#     'items': [{'name': 'باستا صوص ابيض', 'price': 30},
#      {'name': 'سندوتش بطاطس', 'price': 22},
#      {'name': 'برجر', 'price': 10.99},
#      {'name': 'كريب زنجر', 'price': 55},
#      {'name': 'كفتة', 'price': 35},
#      {'name': 'بيتزا فراح', 'price': 75},
#      {'name': 'بيتزا لحمة', 'price': 75},
#      {'name': 'بيتزا مارجريتا', 'price': 70},
#      {'name': 'بينزا تونا', 'price': 85},
#      {'name': 'بيتزا ميكس', 'price': 85},
#      {'name': 'بيتزا ميكس لحمة', 'price': 85}]},
#    {'id': 8,
#     'category': 'desserts of Africanno',
#     'items': [{'name': 'مولتن كيك', 'price': 45},
#      {'name': 'تشيز كيك', 'price': 40},
#      {'name': 'كاب كيك', 'price': 30},
#      {'name': 'فطيرة شكولاتة', 'price': 35}]},
#    {'id': 9,
#     'category': 'drinks of Africanno',
#     'items': [{'name': 'ايسد كوفي', 'price': 10},
#      {'name': 'سموزي', 'price': 30},
#      {'name': 'شاي', 'price': 10},
#      {'name': 'قهوة', 'price': 10},
#      {'name': 'بيبسي', 'price': 5},
#      {'name': 'نسكافيه', 'price': 15}]}]},
#  {'tag': 'menu_english',
#   'patterns': ["what's on the menu?",
#    'How much does it cost?',
#    'What are the prices now?',
#    'Can I view the menu?',
#    'What is the menu of each restaurant?',
#    "What dishes are available at 'Witch' restaurant?",
#    "I'd like to know the menu offerings at 'witch' Can you provide that information?"],
#   'responses': [{'id': 1,
#     'category': 'Meals of Witch',
#     'items': [{'name': 'white sauce pasta', 'price': 30},
#      {'name': 'fried potatoes sandwich', 'price': 22},
#      {'name': 'burger', 'price': 10.99},
#      {'name': 'zenger creb', 'price': 55},
#      {'name': 'kofta', 'price': 35},
#      {'name': 'chicken pizza', 'price': 75},
#      {'name': 'beef pizza', 'price': 75},
#      {'name': 'margherita pizza', 'price': 70},
#      {'name': 'tuna pizza', 'price': 85},
#      {'name': 'pizza mix chicken', 'price': 85},
#      {'name': 'pizza mix beef', 'price': 85}]},
#    {'id': 2,
#     'category': 'desserts of Witch',
#     'items': [{'name': 'Chocolate Lava Cake', 'price': 45},
#      {'name': 'Cheesecake', 'price': 40},
#      {'name': 'cupcake', 'price': 30},
#      {'name': 'chocolate pizza', 'price': 35}]},
#    {'id': 3,
#     'category': 'drinks of Witch',
#     'items': [{'name': 'Iced Coffee', 'price': 10},
#      {'name': 'any Fruit Smoothie', 'price': 30},
#      {'name': 'tea', 'price': 10},
#      {'name': 'coffee', 'price': 10},
#      {'name': 'cola', 'price': 5},
#      {'name': 'latte', 'price': 15}]},
#    {'id': 4,
#     'category': 'Meals of Marwa',
#     'items': [{'name': 'white sauce pasta', 'price': 30},
#      {'name': 'fried potatoes sandwich', 'price': 22},
#      {'name': 'burger', 'price': 10.99},
#      {'name': 'zenger creb', 'price': 55},
#      {'name': 'kofta', 'price': 35},
#      {'name': 'chicken pizza', 'price': 75},
#      {'name': 'beef pizza', 'price': 75},
#      {'name': 'margherita pizza', 'price': 70},
#      {'name': 'tuna pizza', 'price': 85},
#      {'name': 'pizza mix chicken', 'price': 85},
#      {'name': 'pizza mix beef', 'price': 85}]},
#    {'id': 5,
#     'category': 'desserts of Marwa',
#     'items': [{'name': 'Chocolate Lava Cake', 'price': 45},
#      {'name': 'Cheesecake', 'price': 40},
#      {'name': 'cupcake', 'price': 30},
#      {'name': 'chocolate pizza', 'price': 35}]},
#    {'id': 6,
#     'category': 'drinks of Marwa',
#     'items': [{'name': 'Iced Coffee', 'price': 10},
#      {'name': 'any Fruit Smoothie', 'price': 30},
#      {'name': 'tea', 'price': 10},
#      {'name': 'coffee', 'price': 10},
#      {'name': 'cola', 'price': 5},
#      {'name': 'latte', 'price': 15}]},
#    {'id': 7,
#     'category': 'Meals of Africanno',
#     'items': [{'name': 'white sauce pasta', 'price': 30},
#      {'name': 'fried potatoes sandwich', 'price': 22},
#      {'name': 'burger', 'price': 10.99},
#      {'name': 'zenger creb', 'price': 55},
#      {'name': 'kofta', 'price': 35},
#      {'name': 'chicken pizza', 'price': 75},
#      {'name': 'beef pizza', 'price': 75},
#      {'name': 'margherita pizza', 'price': 70},
#      {'name': 'tuna pizza', 'price': 85},
#      {'name': 'pizza mix chicken', 'price': 85},
#      {'name': 'pizza mix beef', 'price': 85}]},
#    {'id': 8,
#     'category': 'desserts of Africanno',
#     'items': [{'name': 'Chocolate Lava Cake', 'price': 45},
#      {'name': 'Cheesecake', 'price': 40},
#      {'name': 'cupcake', 'price': 30},
#      {'name': 'chocolate pizza', 'price': 35}]},
#    {'id': 9,
#     'category': 'drinks of Africanno',
#     'items': [{'name': 'Iced Coffee', 'price': 10},
#      {'name': 'any Fruit Smoothie', 'price': 30},
#      {'name': 'tea', 'price': 10},
#      {'name': 'coffee', 'price': 10},
#      {'name': 'cola', 'price': 5},
#      {'name': 'latte', 'price': 15}]}]},
#  {'tag': 'el_marwa_location_arabic',
#   'patterns': ['حاسبات',
#    'مبنى طب 1',
#    'مبنى طب 2',
#    'مدرج 13',
#    'مدرج 14',
#    'مدرج 17'],
#   'responses': ['المروة اقرب حاجة لحاسبات و طب 1 و 2، مدرج 13 و 14.']},
#  {'tag': 'el_marwa_location_english',
#   'patterns': ['Computer Science',
#    'Medicine',
#    'Hall 13',
#    'Hall 14',
#    'Hall 17',
#    'where is el marwa located?'],
#   'responses': ['El Marwa is right next to Computer Science, Medicine, Hall 13, 14, and 17.']},
#  {'tag': 'witch_restaurant_location_arabic',
#   'patterns': ['حقوق', 'مدرج 15', 'مدرج 8', 'مدرج 10', 'كلية التربية'],
#   'responses': ['مطعم ويتش اقرب مكان من  مدرج 15، 8، و 10، كلية حقوق، وكلية التربية.']},
#  {'tag': 'witch_restaurant_location_english',
#   'patterns': ['faculty of education',
#    'faculty of law',
#    'Hall 8',
#    'Hall 10',
#    'Hall 15',
#    'can you tell me witch location?'],
#   'responses': ['Witch is close to the faculty of Education, Law, as well as Hall 8, 10, and 15.']},
#  {'tag': 'the_mall_location_arabic',
#   'patterns': ['صيدلة', 'خدمة اجتماعية', 'مدرج 6'],
#   'responses': ['المول اقرب مكان من كلية صيدلة و خدمة اجتماعية و مدرج 6.']},
#  {'tag': 'the_mall_location_english',
#   'patterns': ['faculty of Pharmacy',
#    'Social work',
#    'Hall 6',
#    'can you tell me the mall location?'],
#   'responses': ['The Mall is located near the faculty of Pharmacy, Social work, and Hall 6.']},
#  {'tag': 'africana_location_arabic',
#   'patterns': ['العلوم', 'فصول ومعامل', 'مدرج 18'],
#   'responses': ['أفريكانا اقرب مكان من كلية العلوم، فصول ومعامل، ومدرج 18.']},
#  {'tag': 'africana_location_english',
#   'patterns': ['faculty of Science', 'Classes and Labs', 'Hall 18'],
#   'responses': ['Africana is located near the faculty of Science, Classes and Labs, and Hall 18.']},
#  {'tag': 'thank_you_arabic',
#   'patterns': ['شكرا'],
#   'responses': ['العفو,  قولي لو عندك أسئلة تانية']},
#  {'tag': 'thank_you_english',
#   'patterns': ['Thank you'],
#   'responses': ["You're welcome! If you have any more questions, feel free to ask."]},
#  {'tag': 'info',
#   'patterns': ['tell me about rafiki',
#    'tell rafiki',
#    'who is rafiki',
#    'rafiki website'],
#   'responses': ['Rafiki is an online platform designed to assist students during their academic journey. It provides resources, communication tools, and guidance for college life and career opportunities.',
#    'Rafiki is a comprehensive website aimed at supporting students throughout their educational experience, offering resources, communication features, and career guidance.',
#    'Rafiki is a student-centric website offering various tools, resources, and communication channels to enhance the academic experience and facilitate career development.'],
#   'context_set': ''},
#  {'tag': 'team',
#   'patterns': ['who is behind rafiki',
#    'behind rafiki',
#    'tell me about team rafiki',
#    'tell team rafiki',
#    'team members of rafiki',
#    'team members rafiki',
#    "rafiki's team",
#    'rafiki team'],
#   'responses': ['The team behind Rafiki consists of dedicated individuals passionate about supporting students. They work on providing resources, communication channels, and career support to aid students in their academic journey.',
#    'The team at Rafiki is committed to helping students. They manage resources, communication tools, and career guidance to support students throughout their educational experience.',
#    "Rafiki's team comprises professionals focused on assisting students. They provide resources, communication channels, and career guidance to enhance the academic experience."],
#   'context_set': ''},
#  {'tag': 'rafiki_scoop',
#   'patterns': ['who can access rafiki',
#    'access rafiki',
#    'who can use rafiki',
#    'use rafiki',
#    'rafiki users',
#    'rafiki membership'],
#   'responses': ['Rafiki is accessible to all current students, graduates, doctors, sponsors, and others associated with the college.',
#    'All college members have access to Rafiki.',
#    'Rafiki is available for students interested in academic insights and graduates seeking job opportunities.'],
#   'context_set': ''},
#  {'tag': 'rafiki_login',
#   'patterns': ['how to login rafiki',
#    'login rafiki',
#    'access rafiki',
#    'login process for rafiki',
#    'login process rafiki',
#    'How to create an account on rafiki',
#    'create account rafiki',
#    'steps to access rafiki',
#    'steps access rafiki'],
#   'responses': ["To log in to Rafiki, visit the website and click on the 'Log In' button.",
#    'Access Rafiki by logging in through the website.',
#    "To join Rafiki, visit the website and fill in your details after clicking 'Log In'."],
#   'context_set': ''},
#  {'tag': 'rafiki_social',
#   'patterns': ['social media of rafiki',
#    'social media rafiki',
#    "rafiki's social pages",
#    'rafiki social pages',
#    'rafiki on social networks',
#    'rafiki social networks'],
#   'responses': ["Rafiki's Facebook page: https://www.facebook.com/rafikiFCAIHu",
#    "Rafiki's Instagram page: https://www.instagram.com/rafiki_fcai/?utm_source=ig_web_button_share_sheet&igshid=OGQ5ZDc2ODk2ZA==",
#    'Contact Rafiki via email: rafiki.questions@gmail.com'],
#   'context_set': ''},
#  {'tag': 'rafiki_communicate',
#   'patterns': ['how to communicate with rafiki',
#    'communicate rafiki',
#    'contact team rafiki',
#    'talk to team rafiki',
#    'talk team rafiki'],
#   'responses': ['You can contact Rafiki via email at rafiki.questions@gmail.com.'],
#   'context_set': ''},
#  {'tag': 'rafiki_chat',
#   'patterns': ['what is rafiki chat',
#    'rafiki chat',
#    'info about rafiki chat',
#    'info rafiki chat',
#    'rafiki chat',
#    'purpose of rafiki chat',
#    'purpose rafiki chat'],
#   'responses': ['Rafiki chat helps students manage their college life effectively by providing information about their academic year, paperwork, schedules, and locations within the college.',
#    'Rafiki chat is a flexible and friendly tool designed to support students in various aspects of their educational journey.',
#    'Rafiki chat provides information about university schedules and course details.'],
#   'context_set': ''},
#  {'tag': 'rafiki_feedback',
#   'patterns': ['how to give feedback to rafiki',
#    'give feedback rafiki',
#    'share my thoughts on rafiki',
#    'share thoughts rafiki',
#    'rafiki feedback',
#    'provide suggestions for rafiki',
#    'provide suggestions rafiki'],
#   'responses': ['We appreciate your feedback! Please email us at feedback@rafiki.com to share your thoughts and suggestions.',
#    'Your feedback is valuable to us. You can provide your suggestions to improve Rafiki by emailing us at feedback@rafiki.com.'],
#   'context_set': ''},
#  {'tag': 'rafiki_support',
#   'patterns': ['need help with rafiki',
#    'need help rafiki',
#    'require assistance on rafiki',
#    'require assistance rafiki',
#    'help with rafiki',
#    'help rafiki',
#    'technical support for rafiki',
#    'technical support rafiki',
#    'help'],
#   'responses': ['For any assistance or technical support regarding Rafiki, please reach out to our support team at support@rafiki.com.',
#    'Facing issues with Rafiki? Contact our support team at support@rafiki.com for assistance.'],
#   'context_set': ''},
#  {'tag': '', 'patterns': [], 'responses': [], 'context_set': ''},
#  {'tag': 'سلامات',
#   'patterns': ['بقولك',
#    'ينفع اسأل سؤال',
#    'ياصاحبي بقولك',
#    'بقولك اية',
#    'عندي سؤال',
#    'بقولك يا زميلي'],
#   'responses': ['اتفضل/ي يا حبيب اخوك/ي',
#    'قول/ي',
#    'بيتك ومطرحك قولي',
#    'يا سلام اللي انت عاوزة',
#    'اتفضل واحلي اجابة ليك يا باشا',
#    ''],
#   'context_set': ''},
#  {'tag': 'الشكر',
#   'patterns': ['شكرا', 'تسلم', 'تعبتك معايا', 'زي الفل كدا', 'تسلم يا صاحبي'],
#   'responses': ['العفو علي اية',
#    'العفو , متغيبش كتير بقا ابقا تعال',
#    'فرحت بسؤالك ليا',
#    'كانت مناقشة مية مية ',
#    'العفو,اسألتك كانت لوز اللوز'],
#   'context_set': ''},
#  {'tag': 'نكت بايخة',
#   'patterns': ['قولي نكته رخمه',
#    'ما تقول نكتة بايخة',
#    'انا زهقان',
#    'سليني',
#    'قولي اي حاجة ',
#    'اهري في اي حاجة',
#    'نكته باردة',
#    'نكتة رخمه',
#    'نكته بايخة',
#    'ملان',
#    'جاضض'],
#   'responses': ['مرة واحد حب يطور الهليكوبتر شال المروحة وركب تكييف',
#    'واحد راح يوكل أحد المحامين، راح لقاه صايم',
#    'مرة واحد طلب من الجرسون واحد شاء ثقيل قاله تعالي شيلة معايا',
#    'مرة حلة في شاطت راحت جابت جول',
#    'مره اثنين اصحاب ماشيين سوا واحد سوداني والثاني بندق'],
#   'context_set': ''},
#  {'tag': 'الغاز قصيرة',
#   'patterns': ['قولي لغز',
#    'قولي فزورة ',
#    'لغز',
#    'فزورة',
#    'حاجة تشغل الدماغ',
#    'حاجة للذكاء كدا'],
#   'responses': ['يعتبر جزء من الماء ولكن اذا تركته في الماء يموت ، ما هو هذا الشيئ',
#    'ما هو الشيئ الذي لا يمكن لك ان تراه ولكن كل من حولك يرونه',
#    'شيئ بامكانه ان يتحدث بكل اللغات في العالم ، ما هو هذا الشيئ',
#    'نوع معين من الحيوانات ينام مرتديا حذائه',
#    'ما هو الشيئ الذي يملك رقبة ولكن ليس له رأس؟'],
#   'context_set': ''},
#  {'tag': 'نكت حلوة',
#   'patterns': ['قولي نكنه حلوه',
#    ' ما تقول نكتة تضحكني',
#    'انا زهقان',
#    'سليني',
#    'قولي اي حاجة ',
#    'اهري في اي حاجة',
#    'نكته تضحك',
#    'نكتة حلوة ',
#    'نكته تغير المود',
#    'ملان',
#    'جاضض',
#    'نكتة'],
#   'responses': ['مرة واحد كل ما ينظر على البرق يبتسم، تاريه يعتقد البرق بيصوره',
#    'بخيل قال لابنة هاتلى بقرش جبنة.. ابنه راح ورجع.. قاله البقال بيقولى خلى ابوك يجى يلحس السكينة',
#    'بلدايتنا اشترى موبايل سامسونج راح بعت رسالة لخطيبته متتصليش على النوكيا علشان بيعته',
#    'فيه واحد محشش دخل البيت متاخر فتحتله اخته الباب قام وضربها قالها ليه متاخره',
#    'محشش مراته ولدت توأم من الفرحة قال للدكتور على الطلاق لتنقيلك واحد'],
#   'context_set': ''},
#  {'tag': 'ميمز علي الكلية',
#   'patterns': ['ميمز كلية ',
#    'تريقة كلية',
#    'ضحك علي الكلية',
#    'ضحك خام علي الكلية'],
#   'responses': ['موقع الكلية ميمز: https://www.facebook.com/profile.php?id=100070317504395'],
#   'context_set': ''},
#  {'tag': 'Encouraging sentences',
#   'patterns': ['share some encouraging sentences',
#    'encourageing  sentences',
#    'encourage me',
#    "I can't do anything"],
#   'responses': ['Every new day is another chance to change your life. كل يوم جديد هو فرصة أخرى لتغيير حياتك',
#    'You are capable of achieving great things أنت قادر على تحقيق أشياء عظيمة.',
#    'Believe in yourself and your abilities.آمن بنفسك وبقدراتك',
#    'Every challenge you face is an opportunity to grow. كل تحدي تواجهه فرصة للنمو ',
#    'Your determination will lead you to success.إصرارك سيقودك إلى النجاح',
#    'You have the strength to overcome any obstacle.لديك القوة لتتغلب على أي عقبة'],
#   'context_set': ''}]

# %% [markdown]
# **Embedding the responses and patterns**

# %%
from langchain.schema import Document
from langchain.vectorstores import Chroma
from langchain.embeddings import HuggingFaceEmbeddings
import os


def prepare_documents(intents):
    documents = []
    for intent in intents:
        for pattern in intent["patterns"]:
            documents.append(Document(page_content=pattern, metadata={"tag": intent["tag"][0], "responses": str(intent["responses"])}))
    return documents

documents = prepare_documents(intents)

embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")

# Define the persist directory
persist_directory = os.path.join(os.getcwd(), "chroma_db")

# Create the Chroma vector store with the persist_directory
vectorstore = Chroma.from_documents(documents=documents,
                                    embedding=HuggingFaceEmbeddings(),
                                    persist_directory=persist_directory)

# Persist the database to disk
vectorstore.persist()
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# <ipython-input-4-fd49f9770ca9>:23: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embedding=HuggingFaceEmbeddings(),
# <ipython-input-4-fd49f9770ca9>:27: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vectorstore.persist()

# %%
# Define the persist directory
persist_directory = os.path.join(os.getcwd(), "chroma_db")

# Create the HuggingFaceEmbeddings instance explicitly specifying the model name
embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")

# Load the Chroma vector store from the persist_directory
vectorstore = Chroma(persist_directory=persist_directory, embedding_function=embedding_model)

# Use the vector store as a retriever
retriever = vectorstore.as_retriever()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# <ipython-input-7-f42a7926e317>:8: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vectorstore = Chroma(persist_directory=persist_directory, embedding_function=embedding_model)

# %% [markdown]
# **LLM**

# %%
from langchain.schema.runnable import RunnableLambda
import google.generativeai as genai

genai.configure(api_key="AIzaSyAQSxfrS_rE8uzhCbTXJA9hOAelM2NqXPM")
model = genai.GenerativeModel('gemini-1.5-flash')

def generate_text(text):
  response = model.generate_content(text.text)
  return response.text

llm = RunnableLambda(func=generate_text)

# %% [markdown]
# Prompt **Template**

# %%
from langchain.prompts import PromptTemplate

prompt = PromptTemplate(
    input_variables=["context", "student_query"],
    template="""
    You are a student at a university. You answer questions based on the following context:

    Context:
    {context}

    Student Question:
    {student_query}

    Provide a clear and helpful answer to the student's question if question about labs or halls or rooms only say mentiond information no thing else.
    """
)

# %% [markdown]
# **Chain**

# %%
from langchain_core.runnables import RunnableMap


retriever = vectorstore.as_retriever()

def format_docs(docs):
    return "\n\n".join(doc.metadata['responses'] for doc in docs)

rag_chain = (
    {"context": retriever | format_docs, "student_query": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %%
print(rag_chain.invoke("i want to eat pasta"))
# Out:
# You should try Witch, it has the best reviews for pasta.
